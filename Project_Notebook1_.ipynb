# %% [markdown]
# #Data Cleaning John Preston

# %%
#Importing libraries
import os

import pandas as pd

# %%
#Mounting Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# root_dir is the path to your My_Drive folder.
root_dir = "/content/drive/My Drive/"

#storing the data folder in the Colab Notebooks directory at the top level of the Google Drive
data_folder = root_dir + "Colab Notebooks/MPP Science Replication Package/Data/"

# change directory to the data folder
os.chdir(data_folder)

# %%
def dta_to_csv(dta_file_path):
  """
  takes a path to a .dta file and converts it to a .csv. The result
  is stored a subdirectory of the original directory named "/csv".

  Arguments:
    dta_file_path: Full path to the .dta file

  """

  # get the directory and file name from the full path
  directory_name, file_name = os.path.split(dta_file_path)

  # read the .dta file into a DataFrame
  print("Converting file", dta_file_path)
  data = pd.io.stata.read_stata(dta_file_path)

  # save the DataFrame as a ".csv" to the "csv" directory in the original path (directory_name).
  # And get rid of the ".dta" by slicing the file_name
  data.to_csv(directory_name + "/csv/" +  file_name[:-4] +  ".csv")

# %%
def convert_all_dta_to_csv(data_folder):
  """
  Traverse the directory that has path name data_folder. Look for
  .dta files and call dta_to_csv() to convert them to .csv
  """

  # Walk the directory structure
  for root, direc, files in os.walk(data_folder):
    for file in files:
      file_path = os.path.join(root, file)

      # split the file into its name and extension
      filename, extension = os.path.splitext(file)

      # does the file have a .dta extension
      if extension.lower() == ('.dta'):
        dir_path = root

        # Create a 'csv' subdirectory if it doesn't exist
        csv_dir_path = os.path.join(dir_path, 'csv')
        if not os.path.exists(csv_dir_path):
          os.makedirs(csv_dir_path)

        # call the conversion function
        dta_to_csv(file_path)

# call the function to do the conversion
convert_all_dta_to_csv(data_folder)
# Out:
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Randomization and heterogeneity.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/CCTV/cctv_baseline data.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/CCTV/cctv_full data.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Citizen survey/citizen_full data.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Citizen survey/citizen_caw rates.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Admin/admin_long data.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Admin/admin_wide data.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Police survey/police_baseline data.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Police survey/police_full data.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Police survey/police_station personnel data.dta
# Converting file /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/User survey/user survey_endline data.dta

# %% [markdown]
# #Data Cleaning: Admin_long, Police_full, Police_baseline, and Citizen_full.

# %%
def list_datasets(data_folder):
    """
    List all dataset files (.csv, .dta, .xlsx) in the data_folder directory.
    """
    # Supported dataset extensions
    dataset_extensions = ['.csv']

    # Walk through the directory
    for root, dirs, files in os.walk(data_folder):
        for file in files:
            # Split file name and extension
            filename, extension = os.path.splitext(file)

            # If the extension is in the supported list, print the file path
            if extension.lower() in dataset_extensions:
                print(os.path.join(root, file))


# List the datasets available in the folder
list_datasets(data_folder)
# Out:
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/admin_long.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/police_full.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/police_base.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/citizen_full.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/CCTV/csv/cctv_baseline data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/CCTV/csv/cctv_full data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Citizen survey/csv/citizen_caw rates.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Citizen survey/csv/citizen_full data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Admin/csv/admin_long data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Admin/csv/admin_wide data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Police survey/csv/police_baseline data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Police survey/csv/police_full data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Police survey/csv/police_station personnel data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/User survey/csv/user survey_endline data.csv
# /content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/csv/Randomization and heterogeneity.csv

# %%
# Observing and cleaning of Admin_long dataset
admin_long_data = '/content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Admin/csv/admin_long data.csv'

#Creating df for admin long data
admin_long_df = pd.read_csv(admin_long_data)

# %%
#Using head() to get overview of df
admin_long_df.head()
# Out:
#    Unnamed: 0       month  fir_overall_count  fir_caw_count  \
# 0           0  2019-06-01                 35              8
# 1           1  2019-11-01                 29             10
# 2           2  2018-10-01                 26              8
# 3           3  2018-11-01                 27              8
# 4           4  2020-05-01                 32              6
#
#    fir_bywomen_count  arrest_count  dir_count  ncr_count  dial100_count  \
# 0                  5            20          0        100           40.0
# 1                  4            10          1          0           35.0
# 2                  3            12          0         72           25.0
# 3                  4            12          0         64           41.0
# 4                  4            10          0         22           55.0
#
#    ps_code  ...  dist_urban strat_pca  treatment           group dist_id  \
# 0   1001.0  ...         1.0 -0.234041  Treatment  women officers  1000.0
# 1   1001.0  ...         1.0 -0.234041  Treatment  women officers  1000.0
# 2   1001.0  ...         1.0 -0.234041  Treatment  women officers  1000.0
# 3   1001.0  ...         1.0 -0.234041  Treatment  women officers  1000.0
# 4   1001.0  ...         1.0 -0.234041  Treatment  women officers  1000.0
#
#   implement_quality  training_score  comm_outreach_strength  regular_whd  \
# 0               9.0        2.916667                     2.2          0.0
# 1               9.0        2.916667                     2.2          0.0
# 2               9.0        2.916667                     2.2          0.0
# 3               9.0        2.916667                     2.2          0.0
# 4               9.0        2.916667                     2.2          0.0
#
#    women_whd
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#
# [5 rows x 22 columns]

# %%
#Checking the shape of admin log data
admin_long_df.shape
# Out:
# (4500, 22)

# %%
#Overview of Data types and other information
admin_long_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              4500 non-null   int64
#  1   month                   4500 non-null   object
#  2   fir_overall_count       4500 non-null   int64
#  3   fir_caw_count           4500 non-null   int64
#  4   fir_bywomen_count       4500 non-null   int64
#  5   arrest_count            4500 non-null   int64
#  6   dir_count               4500 non-null   int64
#  7   ncr_count               4500 non-null   int64
#  8   dial100_count           4500 non-null   float64
#  9   ps_code                 4500 non-null   float64
#  10  population              4500 non-null   int64
#  11  urban                   4500 non-null   object
#  12  dist_urban              4500 non-null   float64
#  13  strat_pca               4500 non-null   float64
#  14  treatment               4500 non-null   object
#  15  group                   4500 non-null   object
#  16  dist_id                 4500 non-null   float64
#  17  implement_quality       4500 non-null   float64
#  18  training_score          4500 non-null   float64
#  19  comm_outreach_strength  4500 non-null   float64
#  20  regular_whd             4500 non-null   float64
#  21  women_whd               4500 non-null   float64
# dtypes: float64(10), int64(8), object(4)
# memory usage: 773.6+ KB

# %%
#Overview of basic staistics
admin_long_df.describe().T
# Out:
#                          count          mean           std           min  \
# Unnamed: 0              4500.0  2.249500e+03   1299.182435      0.000000
# fir_overall_count       4500.0  3.333067e+01     23.118133      0.000000
# fir_caw_count           4500.0  3.958667e+00      3.754298      0.000000
# fir_bywomen_count       4500.0  2.606667e+00      2.065057      0.000000
# arrest_count            4500.0  3.590444e+00      4.861089      0.000000
# dir_count               4500.0  5.071111e-01      2.100433      0.000000
# ncr_count               4500.0  4.377689e+01     34.747282      0.000000
# dial100_count           4500.0  2.679978e+01     20.344907      0.000000
# ps_code                 4500.0  5.857167e+03   3109.786359   1001.000000
# population              4500.0  1.300729e+05  86182.930694  23565.000000
# dist_urban              4500.0  8.600000e+00      4.896801      1.000000
# strat_pca               4500.0  3.157778e-09      1.377266     -2.355807
# dist_id                 4500.0  5.766667e+03   3059.206823   1000.000000
# implement_quality       4500.0  4.933333e+00      3.702663      0.000000
# training_score          4500.0  2.098003e+00      1.233321      0.000000
# comm_outreach_strength  4500.0  1.188722e+00      1.046705      0.000000
# regular_whd             4500.0  3.388889e-01      0.473385      0.000000
# women_whd               4500.0  3.277778e-01      0.469456      0.000000
#
#                                  25%            50%            75%  \
# Unnamed: 0               1124.750000    2249.500000    3374.250000
# fir_overall_count          18.000000      28.000000      43.000000
# fir_caw_count               1.000000       3.000000       6.000000
# fir_bywomen_count           1.000000       2.000000       4.000000
# arrest_count                0.000000       2.000000       5.000000
# dir_count                   0.000000       0.000000       0.000000
# ncr_count                  19.000000      36.000000      59.000000
# dial100_count              13.000000      21.000000      35.000000
# ps_code                  3045.750000    5090.500000    8135.250000
# population              76491.500000  111183.500000  151937.000000
# dist_urban                  4.000000       8.000000      12.000000
# strat_pca                  -1.110262      -0.125405       0.993797
# dist_id                  3000.000000    5000.000000    8000.000000
# implement_quality           0.000000       7.000000       8.000000
# training_score              1.181818       2.174242       3.272622
# comm_outreach_strength      0.000000       1.175000       2.150000
# regular_whd                 0.000000       0.000000       1.000000
# women_whd                   0.000000       0.000000       1.000000
#
#                                   max
# Unnamed: 0                4499.000000
# fir_overall_count          419.000000
# fir_caw_count               23.000000
# fir_bywomen_count           11.000000
# arrest_count                52.000000
# dir_count                   33.000000
# ncr_count                  243.000000
# dial100_count              254.000000
# ps_code                  12180.000000
# population              545000.000000
# dist_urban                  18.000000
# strat_pca                    3.986043
# dist_id                  12000.000000
# implement_quality            9.000000
# training_score               4.583334
# comm_outreach_strength       3.330000
# regular_whd                  1.000000
# women_whd                    1.000000

# %%
#Checking the value count for our variables: month and fir_bywomen
month_counts = admin_long_df['month'].value_counts()
print(month_counts)

fir_bywomen_counts = admin_long_df['fir_bywomen_count'].value_counts()
print(fir_bywomen_counts)
# Out:
# month
# 2019-06-01    180
# 2019-10-01    180
# 2019-02-01    180
# 2019-08-01    180
# 2020-04-01    180
# 2020-01-01    180
# 2019-12-01    180
# 2018-07-01    180
# 2019-01-01    180
# 2019-04-01    180
# 2020-02-01    180
# 2018-05-01    180
# 2018-12-01    180
# 2019-11-01    180
# 2018-09-01    180
# 2019-09-01    180
# 2020-03-01    180
# 2019-07-01    180
# 2018-06-01    180
# 2019-03-01    180
# 2018-08-01    180
# 2020-05-01    180
# 2018-11-01    180
# 2018-10-01    180
# 2019-05-01    180
# Name: count, dtype: int64
# fir_bywomen_count
# 1     841
# 2     808
# 3     759
# 0     748
# 4     520
# 5     391
# 6     218
# 7     122
# 8      58
# 9      20
# 10     10
# 11      5
# Name: count, dtype: int64

# %%
# Saving the data to "admin_long_df.csv"
admin_long_df.to_csv('/content/drive/MyDrive/admin_long_df.csv', index=False)

# %%
# Observing and cleaning of Police_full
police_full = '/content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Police survey/csv/police_full data.csv'

#Creating df for Police_full data.
police_full_df = pd.read_csv(police_full)

# %%
#Using head() to get overview of df
police_full_df.head()
# Out:
#    Unnamed: 0      uid  gender             e_wcase     e_effective  \
# 0           0  2240137    male  too much attention  very effective
# 1           1  2240133    male  too much attention  very effective
# 2           2  2240136    male  too much attention  very effective
# 3           3  2240132  female  too much attention  very effective
# 4           4  2240134    male  too much attention  very effective
#
#   e_false_case     e_helpful        e_add_officer    e_add_female  \
# 0       common  very helpful       more effective  Less effective
# 1       common  very helpful  much more effective   No difference
# 2     uncommon  very helpful  much more effective  Less effective
# 3       common       helpful  much more effective  Less effective
# 4  very common  very helpful  much more effective   No difference
#
#   e_female_better  ... women_whd b_wcase b_effective  b_pol_impt  \
# 0          female  ...       1.0     2.7         4.5         0.5
# 1          female  ...       1.0     2.7         4.5         0.5
# 2          female  ...       1.0     2.7         4.5         0.5
# 3          female  ...       1.0     2.7         4.5         0.5
# 4          female  ...       1.0     2.7         4.5         0.5
#
#    b_thana_impt  b_sensitivity  b_helpful  b_female_better b_add_officer  \
# 0           0.4            7.3        4.2              2.7           4.5
# 1           0.4            7.3        4.2              2.7           4.5
# 2           0.4            7.3        4.2              2.7           4.5
# 3           0.4            7.3        4.2              2.7           4.5
# 4           0.4            7.3        4.2              2.7           4.5
#
#    b_add_female
# 0           4.6
# 1           4.6
# 2           4.6
# 3           4.6
# 4           4.6
#
# [5 rows x 38 columns]

# %%
#Checking the shape of police_full
police_full_df.shape
# Out:
# (1961, 38)

# %%
#Overview of Data types and checking for any missing values
police_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961 entries, 0 to 1960
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1961 non-null   int64
#  1   uid                     1961 non-null   int64
#  2   gender                  1961 non-null   object
#  3   e_wcase                 1948 non-null   object
#  4   e_effective             1959 non-null   object
#  5   e_false_case            1932 non-null   object
#  6   e_helpful               1958 non-null   object
#  7   e_add_officer           1955 non-null   object
#  8   e_add_female            1956 non-null   object
#  9   e_female_better         1956 non-null   object
#  10  e_taken_seriously       1951 non-null   object
#  11  e_prof_dev              1951 non-null   object
#  12  e_work_help             1954 non-null   object
#  13  e_pol_impt              1961 non-null   float64
#  14  e_thana_impt            1961 non-null   float64
#  15  e_sensitivity           1961 non-null   float64
#  16  ps_code                 1961 non-null   float64
#  17  population              1961 non-null   int64
#  18  urban                   1961 non-null   object
#  19  dist_urban              1961 non-null   float64
#  20  strat_pca               1961 non-null   float64
#  21  treatment               1961 non-null   object
#  22  group                   1961 non-null   object
#  23  dist_id                 1961 non-null   float64
#  24  implement_quality       1295 non-null   float64
#  25  training_score          1961 non-null   float64
#  26  comm_outreach_strength  1295 non-null   float64
#  27  regular_whd             1961 non-null   float64
#  28  women_whd               1961 non-null   float64
#  29  b_wcase                 1961 non-null   float64
#  30  b_effective             1961 non-null   float64
#  31  b_pol_impt              1961 non-null   float64
#  32  b_thana_impt            1961 non-null   float64
#  33  b_sensitivity           1961 non-null   float64
#  34  b_helpful               1961 non-null   float64
#  35  b_female_better         1961 non-null   float64
#  36  b_add_officer           1961 non-null   float64
#  37  b_add_female            1961 non-null   float64
# dtypes: float64(21), int64(3), object(14)
# memory usage: 582.3+ KB

# %%
#There are missing values in the above columns. Checking to see if any missing variables are numerical or important to the project.
police_full_df.describe().T.round(2)
# Out:
#                          count        mean        std         min         25%  \
# Unnamed: 0              1961.0      980.00     566.24        0.00      490.00
# uid                     1961.0  2621999.48  307310.94  2141731.00  2357536.00
# e_pol_impt              1961.0        0.39       0.49        0.00        0.00
# e_thana_impt            1961.0        0.45       0.50        0.00        0.00
# e_sensitivity           1961.0        7.54       2.55        0.00        6.00
# ps_code                 1961.0     5831.55    3104.93     1001.00     3046.00
# population              1961.0   130111.21   86078.79    23565.00    76376.00
# dist_urban              1961.0        8.57       4.89        1.00        4.00
# strat_pca               1961.0        0.01       1.37       -2.36       -1.13
# dist_id                 1961.0     5741.46    3054.43     1000.00     3000.00
# implement_quality       1295.0        7.49       1.35        1.00        7.00
# training_score          1961.0        2.10       1.23        0.00        1.18
# comm_outreach_strength  1295.0        1.81       0.74        0.00        1.20
# regular_whd             1961.0        0.34       0.47        0.00        0.00
# women_whd               1961.0        0.33       0.47        0.00        0.00
# b_wcase                 1961.0        2.68       0.37        1.00        2.50
# b_effective             1961.0        4.61       0.44        1.00        4.36
# b_pol_impt              1961.0        0.38       0.37        0.00        0.00
# b_thana_impt            1961.0        0.40       0.38        0.00        0.00
# b_sensitivity           1961.0        7.04       2.05        1.00        6.00
# b_helpful               1961.0        4.62       0.42        1.00        4.33
# b_female_better         1961.0        2.72       0.45        1.00        2.64
# b_add_officer           1961.0        4.43       0.50        1.00        4.00
# b_add_female            1961.0        4.53       0.53        1.00        4.17
#
#                                50%         75%         max
# Unnamed: 0                  980.00     1470.00     1960.00
# uid                     2554033.00  2845339.00  3257341.00
# e_pol_impt                    0.00        1.00        1.00
# e_thana_impt                  0.00        1.00        1.00
# e_sensitivity                 7.00        9.00       19.00
# ps_code                    5090.00     8135.00    12180.00
# population               111000.00   152000.00   545000.00
# dist_urban                    8.00       12.00       18.00
# strat_pca                    -0.12        1.00        3.99
# dist_id                    5000.00     8000.00    12000.00
# implement_quality             8.00        8.00        9.00
# training_score                2.17        3.31        4.58
# comm_outreach_strength        2.10        2.20        3.33
# regular_whd                   0.00        1.00        1.00
# women_whd                     0.00        1.00        1.00
# b_wcase                       2.80        3.00        3.00
# b_effective                   4.71        5.00        5.00
# b_pol_impt                    0.31        0.60        1.00
# b_thana_impt                  0.36        0.64        1.00
# b_sensitivity                 7.00        8.00       16.00
# b_helpful                     4.75        5.00        5.00
# b_female_better               2.92        3.00        3.00
# b_add_officer                 4.44        5.00        5.00
# b_add_female                  4.64        5.00        5.00

# %%
#Checking the value count for our variables: women_whd, treatment, e_effective, and b_helpful
women_whd_counts = police_full_df['women_whd'].value_counts()
print(women_whd_counts)

treatment_counts = police_full_df['treatment'].value_counts()
print(treatment_counts)

e_effective_counts = police_full_df['e_effective'].value_counts()
print(e_effective_counts)

b_helpful_counts = police_full_df['b_helpful'].value_counts()
print(b_helpful_counts)
# Out:
# women_whd
# 0.0    1316
# 1.0     645
# Name: count, dtype: int64
# treatment
# Treatment    1306
# Control       655
# Name: count, dtype: int64
# e_effective
# very effective      1174
# effective            776
# ineffective            7
# very ineffective       2
# Name: count, dtype: int64
# b_helpful
# 5.000000    742
# 4.000000    378
# 4.545454     54
# 4.454546     54
# 4.500000     51
# 4.750000     46
# 4.727272     42
# 4.363637     41
# 4.666666     40
# 4.818182     33
# 4.909091     33
# 4.900000     32
# 4.636363     31
# 4.444445     29
# 4.583334     27
# 4.700000     23
# 4.833334     23
# 4.300000     22
# 4.555555     22
# 4.800000     21
# 4.600000     18
# 4.888889     18
# 4.083334     18
# 4.846154     15
# 4.166666     14
# 4.777778     14
# 4.333334     12
# 4.416666     11
# 4.250000     10
# 4.272728      9
# 4.538462      9
# 3.000000      8
# 3.909091      6
# 4.230769      6
# 4.375000      6
# 4.200000      6
# 4.916666      6
# 4.692308      6
# 4.714286      5
# 4.461538      5
# 4.181818      4
# 4.400000      4
# 4.090909      3
# 2.000000      2
# 4.875000      1
# 1.000000      1
# Name: count, dtype: int64

# %%
# Saving the data to "police_full_df.csv"
police_full_df.to_csv('/content/drive/MyDrive/police_full.csv',index=False)

# %%
# Observing and cleaning of Police_baseline dataset.
police_base = '/content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Police survey/csv/police_baseline data.csv'

#Creating df for Police_base data.
police_base_df = pd.read_csv(police_base)

# %%
#Getting overview of data set
police_base_df.head()
# Out:
#    Unnamed: 0    b_uid gender  b_pol_impt  b_thana_impt             b_wcase  \
# 0           0  2240165      m         0.0           0.0    enough attention
# 1           1  2240171      m         1.0           1.0    enough attention
# 2           2  2240167      m         1.0           1.0  too much attention
# 3           3  2240172      m         0.0           0.0  too much attention
# 4           4  2240169      m         0.0           0.0  too much attention
#
#       b_effective b_helpful        b_add_officer         b_add_female  ...  \
# 0  very effective   helpful       more effective  much less effective  ...
# 1       effective   helpful  much more effective       less effective  ...
# 2  very effective   helpful       more effective  much less effective  ...
# 3       effective   helpful  much more effective       less effective  ...
# 4       effective   helpful  much more effective  much less effective  ...
#
#   dist_urban  strat_pca  treatment           group  dist_id  \
# 0        1.0  -0.234041  Treatment  women officers   1000.0
# 1        1.0  -0.234041  Treatment  women officers   1000.0
# 2        1.0  -0.234041  Treatment  women officers   1000.0
# 3        1.0  -0.234041  Treatment  women officers   1000.0
# 4        1.0  -0.234041  Treatment  women officers   1000.0
#
#    implement_quality training_score  comm_outreach_strength  regular_whd  \
# 0                9.0       2.916667                     2.2          0.0
# 1                9.0       2.916667                     2.2          0.0
# 2                9.0       2.916667                     2.2          0.0
# 3                9.0       2.916667                     2.2          0.0
# 4                9.0       2.916667                     2.2          0.0
#
#   women_whd
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#
# [5 rows x 27 columns]

# %%
#Checking data shape for police_baseline
police_base_df.shape
# Out:
# (1950, 27)

# %%
#Overview of police_baseline data info
police_base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1950 entries, 0 to 1949
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1950 non-null   int64
#  1   b_uid                   1950 non-null   int64
#  2   gender                  1950 non-null   object
#  3   b_pol_impt              1918 non-null   float64
#  4   b_thana_impt            1924 non-null   float64
#  5   b_wcase                 1948 non-null   object
#  6   b_effective             1943 non-null   object
#  7   b_helpful               1947 non-null   object
#  8   b_add_officer           1948 non-null   object
#  9   b_add_female            1949 non-null   object
#  10  b_female_better         1947 non-null   object
#  11  b_sensitivity           1945 non-null   float64
#  12  uid                     1139 non-null   float64
#  13  attrit                  1950 non-null   float64
#  14  ps_code                 1950 non-null   float64
#  15  population              1950 non-null   int64
#  16  urban                   1950 non-null   object
#  17  dist_urban              1950 non-null   float64
#  18  strat_pca               1950 non-null   float64
#  19  treatment               1950 non-null   object
#  20  group                   1950 non-null   object
#  21  dist_id                 1950 non-null   float64
#  22  implement_quality       1295 non-null   float64
#  23  training_score          1950 non-null   float64
#  24  comm_outreach_strength  1295 non-null   float64
#  25  regular_whd             1950 non-null   float64
#  26  women_whd               1950 non-null   float64
# dtypes: float64(14), int64(3), object(10)
# memory usage: 411.5+ KB

# %%
#Using .describe to view police_baseline
police_base_df.describe().T.round(2)
# Out:
#                          count        mean        std         min         25%  \
# Unnamed: 0              1950.0      974.50     563.06        0.00      487.25
# b_uid                   1950.0  2621708.63  309351.97  2141761.00  2356266.25
# b_pol_impt              1918.0        0.38       0.49        0.00        0.00
# b_thana_impt            1924.0        0.40       0.49        0.00        0.00
# b_sensitivity           1945.0        7.04       2.45        1.00        5.00
# uid                     1139.0  2601023.96  297854.78  2141733.00  2353639.50
# attrit                  1950.0        0.42       0.49        0.00        0.00
# ps_code                 1950.0     5824.59    3132.06     1001.00     3044.00
# population              1950.0   129263.01   84928.09    23565.00    76376.00
# dist_urban              1950.0        8.54       4.93        1.00        4.00
# strat_pca               1950.0        0.00       1.37       -2.36       -1.10
# dist_id                 1950.0     5734.87    3081.08     1000.00     3000.00
# implement_quality       1295.0        7.45       1.37        1.00        7.00
# training_score          1950.0        2.10       1.24        0.00        1.18
# comm_outreach_strength  1295.0        1.80       0.75        0.00        1.20
# regular_whd             1950.0        0.34       0.47        0.00        0.00
# women_whd               1950.0        0.33       0.47        0.00        0.00
#
#                                50%         75%         max
# Unnamed: 0                  974.50     1461.75     1949.00
# b_uid                   2553965.50  2847364.75  3257271.00
# b_pol_impt                    0.00        1.00        1.00
# b_thana_impt                  0.00        1.00        1.00
# b_sensitivity                 7.00        8.00       16.00
# uid                     2551635.00  2753741.50  3257341.00
# attrit                        0.00        1.00        1.00
# ps_code                    5089.00     8136.00    12180.00
# population               111000.00   151916.00   545000.00
# dist_urban                    8.00       12.00       18.00
# strat_pca                    -0.13        1.00        3.99
# dist_id                    5000.00     8000.00    12000.00
# implement_quality             8.00        8.00        9.00
# training_score                2.17        3.31        4.58
# comm_outreach_strength        2.10        2.19        3.33
# regular_whd                   0.00        1.00        1.00
# women_whd                     0.00        1.00        1.00

# %%
#Checking variables associated with the police_baseline dataset(Gender and b_effective). Already checked police_full variables.
gender_counts = police_base_df['gender'].value_counts()
print(gender_counts)

b_effective_counts = police_base_df['b_effective'].value_counts()
print(b_effective_counts)
# Out:
# gender
# m    1713
# f     237
# Name: count, dtype: int64
# b_effective
# very effective                       1210
# effective                             692
# neither effective nor ineffective      29
# ineffective                             7
# very ineffective                        5
# Name: count, dtype: int64

# %%
# Saving the data to "police_base_df.csv"
police_base_df.to_csv('/content/drive/MyDrive/police_base.csv', index=False)

# %%
#Reviewing the last dataset for questions: Citizen_full data
citizen_full = '/content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Citizen survey/csv/citizen_full data.csv'

#Creating df for Citizen_full data.
citizen_full_df = pd.read_csv(citizen_full)

# %%
#Overview of Citizen_full dataset
citizen_full_df.head()
# Out:
#    Unnamed: 0       uid  b_visit  b_pol_handling  b_safety e_urja_knowledge  \
# 0           0  10512011      0.0        0.444444  3.666667               No
# 1           1  10512021      0.0        0.000000  3.666667              NaN
# 2           2  10512031      0.0       -0.111111  2.333333               No
# 3           3  10512041      0.0       -0.200000  3.666667               No
# 4           4  10512051      0.0        0.000000  3.333333              NaN
#
#    e_visit  e_pol_handling  e_safety       spw  ... strat_pca  treatment  \
# 0      0.0            0.50       4.0  0.001526  ... -0.004295  Treatment
# 1      NaN             NaN       NaN  0.001526  ... -0.004295  Treatment
# 2      0.0            0.25       2.0  0.001526  ... -0.004295  Treatment
# 3      0.0             NaN       3.0  0.001526  ... -0.004295  Treatment
# 4      NaN             NaN       NaN  0.001526  ... -0.004295  Treatment
#
#          group  dist_id  implement_quality training_score  \
# 0  regular mhd   3000.0                7.0       3.717949
# 1  regular mhd   3000.0                7.0       3.717949
# 2  regular mhd   3000.0                7.0       3.717949
# 3  regular mhd   3000.0                7.0       3.717949
# 4  regular mhd   3000.0                7.0       3.717949
#
#    comm_outreach_strength  regular_whd women_whd attrited
# 0                    2.15          1.0       0.0      0.0
# 1                    2.15          1.0       0.0      1.0
# 2                    2.15          1.0       0.0      0.0
# 3                    2.15          1.0       0.0      0.0
# 4                    2.15          1.0       0.0      1.0
#
# [5 rows x 27 columns]

# %%
#Checking the shape of the data
citizen_full_df.shape
# Out:
# (6519, 27)

# %%
#Reviewing Citizen_full info and dtypes
citizen_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6519 entries, 0 to 6518
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              6519 non-null   int64
#  1   uid                     6519 non-null   int64
#  2   b_visit                 6519 non-null   float64
#  3   b_pol_handling          6334 non-null   float64
#  4   b_safety                6480 non-null   float64
#  5   e_urja_knowledge        3294 non-null   object
#  6   e_visit                 3376 non-null   float64
#  7   e_pol_handling          3112 non-null   float64
#  8   e_safety                3372 non-null   float64
#  9   spw                     6519 non-null   float64
#  10  e_gender                3376 non-null   object
#  11  hh_id                   6519 non-null   float64
#  12  member_gender           6519 non-null   object
#  13  ps_code                 6519 non-null   float64
#  14  population              6519 non-null   int64
#  15  urban                   6519 non-null   object
#  16  dist_urban              6519 non-null   float64
#  17  strat_pca               6519 non-null   float64
#  18  treatment               6519 non-null   object
#  19  group                   6519 non-null   object
#  20  dist_id                 6519 non-null   float64
#  21  implement_quality       4291 non-null   float64
#  22  training_score          6519 non-null   float64
#  23  comm_outreach_strength  4291 non-null   float64
#  24  regular_whd             6519 non-null   float64
#  25  women_whd               6519 non-null   float64
#  26  attrited                6519 non-null   float64
# dtypes: float64(18), int64(3), object(6)
# memory usage: 1.3+ MB

# %%
#There is alot of data not needed in this dataset. Dropping some of the columns not needed from the dataset.
citizen_full_df = citizen_full_df.drop(columns=['b_safety', 'e_urja_knowledge', 'spw', 'hh_id'])

# %%
#Checking to see if columns were dropped
citizen_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6519 entries, 0 to 6518
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              6519 non-null   int64
#  1   uid                     6519 non-null   int64
#  2   b_visit                 6519 non-null   float64
#  3   b_pol_handling          6334 non-null   float64
#  4   e_visit                 3376 non-null   float64
#  5   e_pol_handling          3112 non-null   float64
#  6   e_safety                3372 non-null   float64
#  7   e_gender                3376 non-null   object
#  8   member_gender           6519 non-null   object
#  9   ps_code                 6519 non-null   float64
#  10  population              6519 non-null   int64
#  11  urban                   6519 non-null   object
#  12  dist_urban              6519 non-null   float64
#  13  strat_pca               6519 non-null   float64
#  14  treatment               6519 non-null   object
#  15  group                   6519 non-null   object
#  16  dist_id                 6519 non-null   float64
#  17  implement_quality       4291 non-null   float64
#  18  training_score          6519 non-null   float64
#  19  comm_outreach_strength  4291 non-null   float64
#  20  regular_whd             6519 non-null   float64
#  21  women_whd               6519 non-null   float64
#  22  attrited                6519 non-null   float64
# dtypes: float64(15), int64(3), object(5)
# memory usage: 1.1+ MB

# %%
#Using .describe to view citizen_full_df
citizen_full_df.describe().T.round(2)
# Out:
#                          count         mean          std          min  \
# Unnamed: 0              6519.0      3259.00      1882.02         0.00
# uid                     6519.0  38617732.64  20188911.78  10512011.00
# b_visit                 6519.0         0.07         0.26         0.00
# b_pol_handling          6334.0         0.33         0.48        -1.00
# e_visit                 3376.0         0.11         0.32         0.00
# e_pol_handling          3112.0         0.54         0.47        -1.00
# e_safety                3372.0         3.19         0.49         1.00
# ps_code                 6519.0      5963.58      3137.80      1001.00
# population              6519.0    130475.79     86245.59     23565.00
# dist_urban              6519.0         8.75         4.92         1.00
# strat_pca               6519.0        -0.01         1.38        -2.36
# dist_id                 6519.0      5871.45      3087.51      1000.00
# implement_quality       4291.0         7.45         1.32         1.00
# training_score          6519.0         2.08         1.23         0.00
# comm_outreach_strength  4291.0         1.81         0.75         0.00
# regular_whd             6519.0         0.34         0.47         0.00
# women_whd               6519.0         0.32         0.47         0.00
# attrited                6519.0         0.48         0.50         0.00
#
#                                 25%          50%          75%          max
# Unnamed: 0                  1629.50      3259.00      4888.50      6518.00
# uid                     21562126.00  40552300.00  50632461.00  80602481.00
# b_visit                        0.00         0.00         0.00         1.00
# b_pol_handling                 0.00         0.33         0.75         1.00
# e_visit                        0.00         0.00         0.00         1.00
# e_pol_handling                 0.20         0.67         1.00         1.00
# e_safety                       3.00         3.33         3.50         4.00
# ps_code                     4048.00      5092.00      8136.00     12180.00
# population                 77000.00    111367.00    151916.00    545000.00
# dist_urban                     5.00         8.00        12.00        18.00
# strat_pca                     -1.13        -0.16         1.00         3.99
# dist_id                     4000.00      5000.00      8000.00     12000.00
# implement_quality              7.00         8.00         8.00         9.00
# training_score                 1.18         2.17         3.20         4.58
# comm_outreach_strength         1.20         2.10         2.19         3.33
# regular_whd                    0.00         0.00         1.00         1.00
# women_whd                      0.00         0.00         1.00         1.00
# attrited                       0.00         0.00         1.00         1.00

# %%
#Checking variables from the dataset that I will be using: B_visit,e_visit, B_pol_handling, e_pol_handling, member_gender
b_visit_counts = citizen_full_df['b_visit'].value_counts()
print(b_visit_counts)

e_visit_counts = citizen_full_df['e_visit'].value_counts()
print(e_visit_counts)

b_pol_handling_counts = citizen_full_df['b_pol_handling'].value_counts().round(2)
print(b_pol_handling_counts)

e_pol_handling_counts = citizen_full_df['e_pol_handling'].value_counts().round(2)
print(e_pol_handling_counts)

member_gender_counts = citizen_full_df['member_gender'].value_counts()
print(member_gender_counts)
# Out:
# b_visit
# 0.0    6039
# 1.0     480
# Name: count, dtype: int64
# e_visit
# 0.0    2999
# 1.0     377
# Name: count, dtype: int64
# b_pol_handling
#  0.000000    938
#  1.000000    901
#  0.500000    329
#  0.333333    314
#  0.666667    272
#  0.888889    171
#  0.250000    169
#  0.444444    162
#  0.555556    160
#  0.111111    139
#  0.777778    134
#  0.222222    132
#  0.125000    120
# -1.000000    117
#  0.750000    116
#  0.375000    114
#  0.285714    103
# -0.333333     99
#  0.428571     99
#  0.166667     98
#  0.571429     91
# -0.250000     88
#  0.625000     88
#  0.142857     80
#  0.200000     78
#  0.714286     78
#  0.600000     76
#  0.857143     76
#  0.400000     69
#  0.833333     68
#  0.800000     67
# -0.111111     66
# -0.500000     62
# -0.125000     60
#  0.875000     60
# -0.222222     57
# -0.142857     56
# -0.666667     46
# -0.444444     37
# -0.166667     37
# -0.285714     34
# -0.375000     33
# -0.750000     27
# -0.428571     26
# -0.200000     24
# -0.555556     23
# -0.400000     21
# -0.777778     18
# -0.571429     17
# -0.625000     14
# -0.600000     14
# -0.800000     12
# -0.714286     12
# -0.875000     10
# -0.833333      8
# -0.888889      7
# -0.857143      7
# Name: count, dtype: int64
# e_pol_handling
#  1.000000    964
#  0.000000    371
#  0.500000    224
#  0.750000    141
#  0.666667    132
#  0.333333    110
#  0.250000     89
#  0.875000     76
#  0.800000     72
#  0.833333     69
#  0.600000     59
#  0.625000     58
#  0.857143     58
#  0.714286     57
#  0.400000     52
#  0.200000     51
#  0.571429     47
#  0.285714     45
# -1.000000     45
#  0.166667     44
#  0.375000     41
#  0.142857     39
#  0.428571     34
#  0.125000     33
# -0.333333     28
# -0.200000     25
# -0.500000     24
# -0.250000     13
# -0.142857     12
# -0.428571     12
# -0.166667     12
# -0.125000     12
# -0.666667     12
# -0.400000     11
# -0.285714      7
# -0.600000      6
# -0.750000      5
# -0.625000      5
# -0.800000      4
# -0.375000      4
# -0.875000      3
# -0.714286      3
# -0.833333      2
# -0.857143      1
# Name: count, dtype: int64
# member_gender
# female    5652
# male       867
# Name: count, dtype: int64

# %%
# Saving the data to "citizen_full_df.csv"
citizen_full_df.to_csv('/content/drive/MyDrive/citizen_full.csv', index=False)
